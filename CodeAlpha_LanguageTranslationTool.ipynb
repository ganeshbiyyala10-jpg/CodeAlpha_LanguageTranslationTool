# %%
# !pip uninstall -y googletrans
# !pip install googletrans-py
# Out:
# Found existing installation: googletrans 4.0.0rc1
# Uninstalling googletrans-4.0.0rc1:
#   Successfully uninstalled googletrans-4.0.0rc1
# Collecting googletrans-py
#   Downloading googletrans-py-4.0.0.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx>=0.22.0 (from googletrans-py)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting h2<5,>=4 (from googletrans-py)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=4->googletrans-py)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=4->googletrans-py)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->googletrans-py) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->googletrans-py) (2026.5.20)
# Collecting httpcore==1.* (from httpx>=0.22.0->googletrans-py)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->googletrans-py) (2.10)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.22.0->googletrans-py)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.22.0->googletrans-py) (4.15.0)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 3.1 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 3.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 5.2 MB/s eta 0:00:00
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Building wheels for collected packages: googletrans-py
#   Building wheel for googletrans-py (setup.py) ... done
#   Created wheel for googletrans-py: filename=googletrans_py-4.0.0-py3-none-any.whl size=13115 sha256=69db4b87a2fc74e0d9aab6d57015e71f466a92d3187c1e5c77ab6ef3393d6bc8
#   Stored in directory: /root/.cache/pip/wheels/d7/77/86/56a6d2caf2420c4f8f062d014fdf011477f213718ef9aae7d2
# Successfully built googletrans-py
# Installing collected packages: hyperframe, hpack, h11, httpcore, h2, httpx, googletrans-py
#   Attempting uninstall: hyperframe
#     Found existing installation: hyperframe 5.2.0
#     Uninstalling hyperframe-5.2.0:
#       Successfully uninstalled hyperframe-5.2.0
#   Attempting uninstall: hpack
#     Found existing installation: hpack 3.0.0
#     Uninstalling hpack-3.0.0:
#       Successfully uninstalled hpack-3.0.0
#   Attempting uninstall: h11
#     Found existing installation: h11 0.9.0
#     Uninstalling h11-0.9.0:
#       Successfully uninstalled h11-0.9.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.9.1
#     Uninstalling httpcore-0.9.1:
#       Successfully uninstalled httpcore-0.9.1
#   Attempting uninstall: h2
#     Found existing installation: h2 3.2.0
#     Uninstalling h2-3.2.0:
#       Successfully uninstalled h2-3.2.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.13.3
#     Uninstalling httpx-0.13.3:
#       Successfully uninstalled httpx-0.13.3
# Successfully installed googletrans-py-4.0.0 h11-0.16.0 h2-4.3.0 hpack-4.1.0 httpcore-1.0.9 httpx-0.28.1 hyperframe-6.1.0

# %%
from googletrans import Translator

translator = Translator()

text = input("Enter text: ")

translated = translator.translate(
    text,
    src='en',
    dest='te'
)

print("Translated Text:")
print(translated.text)
# Out:
# Enter text: good morning
# Translated Text:
# శుభోదయం

# %%
from googletrans import Translator

translator = Translator()

languages = {
    "English": "en",
    "Hindi": "hi",
    "Telugu": "te",
    "Tamil": "ta",
    "French": "fr"
}

text = input("Enter text: ")

print("Available Languages:")
for lang in languages:
    print(lang)

source = input("Source Language: ").title()
target = input("Target Language: ").title()

result = translator.translate(
    text,
    src=languages[source],
    dest=languages[target]
)

print("\nTranslated Text:")
print(result.text)
# Out:
# Enter text: how r u
# Available Languages:
# English
# Hindi
# Telugu
# Tamil
# French
# Source Language: english
# Target Language: hindi
#
# Translated Text:
# आप कैसे हैं
